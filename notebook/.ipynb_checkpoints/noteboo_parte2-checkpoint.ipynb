# %% [markdown]
# # MARATONA BEHIND THE CODE 2020
#
# ## DESAFIO 2: PARTE 2

# %% [markdown]
# ### Introdução

# %% [markdown]
# Na parte 1 deste desafio, você realizou o pré-processamento e o treinamento de um modelo a partir de um conjunto de dados base fornecido. Nesta segunda etapa você irá integrar todas as transformações e eventos de treinamento criados anteriormente em uma Pipeline completa para *deploy* no **Watson Machine Learning**!

# %% [markdown]
# ### Preparação do Notebook

# %% [markdown]
# Primeiro realizaremos a instalação do scikit-learn e a importação das mesmas bibliotecas utilizadas anteriormente

# %%
# !pip install scikit-learn==0.20.0 --upgrade

# %%
import json
import requests
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, cross_validate

# %% [markdown]
# É necessário inserir o conjunto de dados base novamente como um dataframe pandas, seguindo as instruções
#
# ![alt text](https://i.imgur.com/K1DwL9I.png "importing-csv-as-df")
#
# Após a seleção da opção **"Insert to code"**, a célula abaixo será preenchida com o código necessário para importação e leitura dos dados no arquivo .csv como um DataFrame Pandas.

# %%
<< INSIRA O DATASET COMO UM DATAFRAME PANDAS NESTA CÉLULA >>

# %% [markdown]
# ### Construção da Pipeline completa para encapsulamento no WML

# %% [markdown]
# #### Preparando transformações personalizadas para carregamento no WML

# %% [markdown]
# Na etapa anterior, foi mostrado como criar uma transformação personalizada, através da declaração de uma classe Python com os métodos ``fit`` e ``transform``.
#
#     - Código da transformação personalizada DropColumns():
#
#     from sklearn.base import BaseEstimator, TransformerMixin
#     # All sklearn Transforms must have the `transform` and `fit` methods
#     class DropColumns(BaseEstimator, TransformerMixin):
#         def __init__(self, columns):
#             self.columns = columns
#         def fit(self, X, y=None):
#             return self
#         def transform(self, X):
#             # Primeiro realizamos a cópia do dataframe 'X' de entrada
#             data = X.copy()
#             # Retornamos um novo dataframe sem as colunas indesejadas
#             return data.drop(labels=self.columns, axis='columns')
#
# Para integrar esses tipos de transformações personalizadas nas Pipelines do Watson Machine Learning, é necessário primeiramente empacotar seu código personalizado como uma biblioteca Python. Isso pode ser feito facilmente com o uso da ferramenta *setuptools*.
#
# No seguinte repositório git: https://github.com/vnderlev/sklearn_transforms temos todos os arquivos necessários para a criação de um pacote Python, nomeado **my_custom_sklearn_transforms**.
# Esse pacote possui a seguinte estrutura de arquivos:
#
#     /my_custom_sklearn_transforms.egg-info
#         dependency_links.txt
#         not-zip-safe
#         PKG-INFO
#         SOURCES.txt
#         top_level.txt
#     /my_custom_sklearn_transforms
#         __init__.py
#         sklearn_transformers.py
#     PKG-INFO
#     README.md
#     setup.cfg
#     setup.py
#
# O arquivo principal, que irá conter o código das nossas transformadas personalizadas, é o arquivo **/my_custom_sklearn_transforms/sklearn_transformers.py**. Se você acessá-lo no repositório, irá notar que ele contém exatamente o mesmo código declarado na primeira etapa (a classe DropColumns).
#
# Caso você tenha declarado transformações próprias (além da DropColumn fornecida), você deverá adicionar todas as classes dessas transformadas criadas por você nesse mesmo arquivo. Para tal, você deve realizar o fork desse repositório (isso pode ser feito na própria interface Web do Github, clicando no botão conforme a imagem abaixo), e adicionar suas classes personalizadas no arquivo **sklearn_transformers.py**.
#
# ![alt text](https://i.imgur.com/D81E1uM.png "forking-a-repo")
#
# Se você somente fez o uso da transformação fornecida (DropColumns), pode ignorar essa etapa de fork, e seguir utilizando o pacote base fornecido! :)
#
# Após a preparação do seu pacote Python com as suas transformadas personalizadas, substitua o link do repositório git na célula abaixo e execute-a. Caso você não tenha preparado nenhuma nova transformada, execute a célula com o link do repositório já fornecido.
#
# <hr>
#
# **OBSERVAÇÃO**
#
# Caso a execução da célula abaixo retorne um erro de que o repositório já existe, execute:
#
# **!rm -r -f sklearn_transforms**

# %%
# substitua o link abaixo pelo link do seu repositório git (se for o caso)
# !git clone https://github.com/joel021/create_model_to_pipeline.git
# Out:
# Cloning into 'create_model_to_pipeline'...
# remote: Enumerating objects: 44, done.
# remote: Counting objects: 100% (44/44), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 103 (delta 23), reused 31 (delta 11), pack-reused 59
# Receiving objects: 100% (103/103), 16.26 KiB | 5.42 MiB/s, done.
# Resolving deltas: 100% (50/50), done.

# %%
# !cd create_model_to_pipeline
# !ls -ltr
# Out:
# total 1756
# -rw-r--r-- 1 joel joel  76472 ago 22 07:54 modelo_desafio_uninassau.h5
# -rw-r--r-- 1 joel joel 194620 ago 22 07:54 historico_modelo_desafio_uninassau.json
# -rw-r--r-- 1 joel joel 202277 ago 22 07:54 historico_modelo_desafio_uninassau.csv
# -rw-r--r-- 1 joel joel 481715 ago 22 07:54 novo-note.ipynb
# -rw-rw-r-- 1 joel joel 138412 ago 22 08:04 notebook-parte-1.ipynb
# -rw-r--r-- 1 joel joel     72 ago 22 11:02 Untitled.ipynb
# -rw-rw-r-- 1 joel joel 459527 ago 22 14:55 novo_note_desicion_tree.ipynb
# -rw-r--r-- 1 joel joel  27626 ago 22 17:41 notebook2_original.ipynb
# -rw-r--r-- 1 joel joel 194486 ago 22 18:37 noteboo_parte2.ipynb
# drwxr-xr-x 6 joel joel   4096 ago 22 18:38 create_model_to_pipeline

# %% [markdown]
# Para subir o código no WML, precisamos enviar um arquivo .zip com todo o código fonte, então iremos zipar o diretório clonado em seguida:

# %%
# !zip -r create_model_to_pipeline.zip create_model_to_pipeline
# Out:
#   adding: create_model_to_pipeline/ (stored 0%)
#   adding: create_model_to_pipeline/PKG-INFO (deflated 31%)
#   adding: create_model_to_pipeline/my_custom_model.egg-info/ (stored 0%)
#   adding: create_model_to_pipeline/my_custom_model.egg-info/dependency_links.txt (stored 0%)
#   adding: create_model_to_pipeline/my_custom_model.egg-info/SOURCES.txt (deflated 48%)
#   adding: create_model_to_pipeline/my_custom_model.egg-info/PKG-INFO (deflated 33%)
#   adding: create_model_to_pipeline/my_custom_model.egg-info/not-zip-safe (stored 0%)
#   adding: create_model_to_pipeline/my_custom_model.egg-info/top_level.txt (stored 0%)
#   adding: create_model_to_pipeline/.git/ (stored 0%)
#   adding: create_model_to_pipeline/.git/branches/ (stored 0%)
#   adding: create_model_to_pipeline/.git/index (deflated 46%)
#   adding: create_model_to_pipeline/.git/hooks/ (stored 0%)
#   adding: create_model_to_pipeline/.git/hooks/pre-commit.sample (deflated 43%)
#   adding: create_model_to_pipeline/.git/hooks/prepare-commit-msg.sample (deflated 50%)
#   adding: create_model_to_pipeline/.git/hooks/applypatch-msg.sample (deflated 42%)
#   adding: create_model_to_pipeline/.git/hooks/fsmonitor-watchman.sample (deflated 53%)
#   adding: create_model_to_pipeline/.git/hooks/post-update.sample (deflated 27%)
#   adding: create_model_to_pipeline/.git/hooks/update.sample (deflated 68%)
#   adding: create_model_to_pipeline/.git/hooks/pre-push.sample (deflated 50%)
#   adding: create_model_to_pipeline/.git/hooks/pre-receive.sample (deflated 40%)
#   adding: create_model_to_pipeline/.git/hooks/pre-rebase.sample (deflated 59%)
#   adding: create_model_to_pipeline/.git/hooks/commit-msg.sample (deflated 44%)
#   adding: create_model_to_pipeline/.git/hooks/pre-applypatch.sample (deflated 38%)
#   adding: create_model_to_pipeline/.git/info/ (stored 0%)
#   adding: create_model_to_pipeline/.git/info/exclude (deflated 28%)
#   adding: create_model_to_pipeline/.git/config (deflated 33%)
#   adding: create_model_to_pipeline/.git/refs/ (stored 0%)
#   adding: create_model_to_pipeline/.git/refs/heads/ (stored 0%)
#   adding: create_model_to_pipeline/.git/refs/heads/master (stored 0%)
#   adding: create_model_to_pipeline/.git/refs/remotes/ (stored 0%)
#   adding: create_model_to_pipeline/.git/refs/remotes/origin/ (stored 0%)
#   adding: create_model_to_pipeline/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: create_model_to_pipeline/.git/refs/tags/ (stored 0%)
#   adding: create_model_to_pipeline/.git/objects/ (stored 0%)
#   adding: create_model_to_pipeline/.git/objects/info/ (stored 0%)
#   adding: create_model_to_pipeline/.git/objects/pack/ (stored 0%)
#   adding: create_model_to_pipeline/.git/objects/pack/pack-cf7702b95678766d46848f4e613c5b2ff6d0d4ff.idx (deflated 21%)
#   adding: create_model_to_pipeline/.git/objects/pack/pack-cf7702b95678766d46848f4e613c5b2ff6d0d4ff.pack (deflated 3%)
#   adding: create_model_to_pipeline/.git/logs/ (stored 0%)
#   adding: create_model_to_pipeline/.git/logs/refs/ (stored 0%)
#   adding: create_model_to_pipeline/.git/logs/refs/heads/ (stored 0%)
#   adding: create_model_to_pipeline/.git/logs/refs/heads/master (deflated 30%)
#   adding: create_model_to_pipeline/.git/logs/refs/remotes/ (stored 0%)
#   adding: create_model_to_pipeline/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: create_model_to_pipeline/.git/logs/refs/remotes/origin/HEAD (deflated 30%)
#   adding: create_model_to_pipeline/.git/logs/HEAD (deflated 30%)
#   adding: create_model_to_pipeline/.git/description (deflated 14%)
#   adding: create_model_to_pipeline/.git/packed-refs (deflated 11%)
#   adding: create_model_to_pipeline/.git/HEAD (stored 0%)
#   adding: create_model_to_pipeline/.idea/ (stored 0%)
#   adding: create_model_to_pipeline/.idea/misc.xml (deflated 30%)
#   adding: create_model_to_pipeline/.idea/vcs.xml (deflated 22%)
#   adding: create_model_to_pipeline/.idea/.gitignore (stored 0%)
#   adding: create_model_to_pipeline/.idea/inspectionProfiles/ (stored 0%)
#   adding: create_model_to_pipeline/.idea/inspectionProfiles/profiles_settings.xml (deflated 27%)
#   adding: create_model_to_pipeline/.idea/modules.xml (deflated 39%)
#   adding: create_model_to_pipeline/.idea/sklearn_transforms.iml (deflated 31%)
#   adding: create_model_to_pipeline/README.md (deflated 15%)
#   adding: create_model_to_pipeline/setup.cfg (deflated 16%)
#   adding: create_model_to_pipeline/setup.py (deflated 43%)
#   adding: create_model_to_pipeline/my_custom_model/ (stored 0%)
#   adding: create_model_to_pipeline/my_custom_model/__init__.py (stored 0%)
#   adding: create_model_to_pipeline/my_custom_model/custom_dense_model_classifier.py (deflated 69%)

# %% [markdown]
# Com o arquivo zip do nosso pacote carregado no Kernel deste notebook, podemos utilizar a ferramenta pip para instalá-lo, conforme a célula abaixo:

# %%
# !pip install create_model_to_pipeline.zip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Processing ./create_model_to_pipeline.zip
# Building wheels for collected packages: create-model-to-pipeline
#   Building wheel for create-model-to-pipeline (setup.py) ... done
#   Created wheel for create-model-to-pipeline: filename=create_model_to_pipeline-1.0-py3-none-any.whl size=3340 sha256=6a60252121be31dc73adedfb56315b4fabfbee1f6c4a83522c3c3bb9b465393d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-h5wgevku/wheels/05/73/5a/27122a8a88a215c1e7f6e8c90b0746352109e007cea3bf1cdf
# Successfully built create-model-to-pipeline
# Installing collected packages: create-model-to-pipeline
# Successfully installed create-model-to-pipeline-1.0

# %% [markdown]
# Podemos agora realizar a importação do nosso pacote personalizado em nosso notabook!
#
# Iremos importar a transformação DropColumns. Se você possui outras transformações personalizadas, não se esqueça de importá-las!

# %%
from my_custom_model.custom_dense_model_classifier import CreateModel

# %% [markdown]
# #### Declarando a Pipeline
#
# Após a importação das transformações personalizadas como um pacote Python, podemos partir para a declaração da nossa Pipeline.
#
# O processo é bem semelhante ao realizado na primeira etapa, porém com algumas diferenças importantes, então preste bem atenção!
#
# A Pipeline exemplo possui três estágios:
#
#     - remover a coluna "NOME"
#     - imputar "zeros" em todos os valores faltantes
#     - inserir os dados pré-processados como entrada em um modelo treinado
#
# Relembrando, a entrada desta Pipeline será o conjunto cru de dados fornecido exceto a coluna "LABELS" (variável-alvo a ser determinada pelo modelo).
#
# Teremos então 17 valores de entrada **na PIPELINE** (no modelo serão 16 entradas, pois a coluna NAME será removida no primeiro estágio após a transformação DropColumn).
#
#     MATRICULA       - número de quatro algarismos único para cada estudante
#     NOME            - nome completo do estudante
#     FALTAS_DE       - número de faltas na disciplina de ``Direito Empresarial``
#     FALTAS_EM       - número de faltas na disciplina de ``Empreendedorismo``
#     FALTAS_MF       - número de faltas na disciplina de ``Matemática Financeira``
#     MEDIA_DE        - média simples das notas do aluno na disciplina de ``Direito Empresarial`` (0-10)
#     MEDIA_EM        - média simples das notas do aluno na disciplina de ``Empreendedorismo`` (0-10)
#     MEDIA_MF        - média simples das notas do aluno na disciplina de ``Matemática Financeira`` (0-10)
#     HRS_ESTUDO_DE   - horas de estudo particular na disciplina de ``Direito Empresarial``
#     HRS_ESTUDO_EM   - horas de estudo particular na disciplina de ``Empreendedorismo``
#     HRS_ESTUDO_MF   - horas de estudo particular na disciplina de ``Matemática Financeira``
#     REPROVACOES_DE  - número de reprovações na disciplina de ``Direito Empresarial``
#     REPROVACOES_EM  - número de reprovações na disciplina de ``Empreendedorismo``
#     REPROVACOES_MF  - número de reprovações na disciplina de ``Matemática Financeira``
#     LIVROS_TEXTO    - quantidade de livros e textos acessados pelo aluno no sistema da universidade
#     AULAS_AO_VIVO   - horas de aulas ao vivo presenciadas pelo aluno (total em todas as disciplinas)
#     EXERCICIOS      - número de exercícios realizados pelo estudante (total em todas as disciplinas) no sistema da universidade
#
# A saída da Pipeline será um valor estimado para a coluna "LABELS".

# %%
# Preparação dos argumentos para os métodos da biblioteca ``scikit-learn``
df_data_1 = pd.read_csv("../data_asset/dataset_desafio_2.csv")

# %%
X = df_data_1.drop(labels=["PERFIL","MATRICULA","NOME","INGLES", "FALTAS"], axis='columns')
        #('imputer', si)#percebi que não precisava implementar a classe depois que fiz...
Y = df_data_1["PERFIL"].values.ravel()

# %%
# Criação de um objeto ``SimpleImputer``

si = SimpleImputer(
    missing_values=np.nan,  # os valores faltantes são do tipo ``np.nan`` (padrão Pandas)
    strategy='constant',  # a estratégia escolhida é a alteração do valor faltante por uma constante
    fill_value=0,  # a constante que será usada para preenchimento dos valores faltantes é um int64=0.
    verbose=0,
    copy=True
)

si.fit(X=X)

# Reconstrução de um novo DataFrame Pandas com o conjunto importado (df_data_3)
X = pd.DataFrame.from_records(
    data=si.transform(
        X=X
    ),  # o resultado SimpleImputer.transform(<<pandas dataframe>>) é lista de listas
    columns=X.columns  # as colunas originais devem ser conservadas nessa transformação
)

# %%
def nota_proporcional(data):
    d = data.copy()
    for coluna in ["NOTA_DE", "NOTA_MF", "NOTA_GO", "NOTA_EM"]:
        media = data[coluna].median()
        for i in range(len(d[coluna])):
            d.at[i, coluna] = data.at[i, coluna] / media

    return d

### calcular a quantidade total de horas de atividades e sua proporcionalidade
def mesclar_horas(data):
    d = data.copy()
    atividades = list()
    soma_medias = data.H_AULA_PRES.median() + data.TAREFAS_ONLINE.median()
    for i in range(0, len(data["NOTA_DE"])):
        v = (data.at[i, "H_AULA_PRES"] + data.at[i, "TAREFAS_ONLINE"]) / soma_medias
        atividades.append(v)

    d = d.drop(["H_AULA_PRES", "TAREFAS_ONLINE"], axis=1)
    d['ATIVIDADES'] = atividades

    return d

X = mesclar_horas(X)
X = nota_proporcional(X)

# %%
# Criação da nossa pipeline para armazenamento no Watson Machine Learning:
my_pipeline = Pipeline(
    steps=[
        ('create_model', CreateModel(9,900,2500).put_X_Y(X,Y,0.1)), #X,Yinput_size,bath_size,epochs
    ]
)

# %% [markdown]
# Em seguida iremos executar o método `fit()` da Pipeline, realizando o pré-processamento e o treinamento do modelo de uma só vez.

# %%
# Inicialização da Pipeline (pré-processamento e realização do treinamento do modelo)
my_pipeline.fit(X, Y)
# Out:
# Epoch 1/900
# 6/6 [==============================] - 0s 26ms/step - loss: 1.5939 - accuracy: 0.1664 - val_loss: 1.5653 - val_accuracy: 0.1890
# Epoch 2/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.5475 - accuracy: 0.2129 - val_loss: 1.5200 - val_accuracy: 0.2553
# Epoch 3/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.5032 - accuracy: 0.3171 - val_loss: 1.4762 - val_accuracy: 0.5463
# Epoch 4/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.4599 - accuracy: 0.5651 - val_loss: 1.4331 - val_accuracy: 0.5977
# Epoch 5/900
# 6/6 [==============================] - 0s 9ms/step - loss: 1.4169 - accuracy: 0.5966 - val_loss: 1.3904 - val_accuracy: 0.6127
# Epoch 6/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.3744 - accuracy: 0.6124 - val_loss: 1.3477 - val_accuracy: 0.6257
# Epoch 7/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.3321 - accuracy: 0.6186 - val_loss: 1.3057 - val_accuracy: 0.6260
# Epoch 8/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2906 - accuracy: 0.6189 - val_loss: 1.2646 - val_accuracy: 0.6260
# Epoch 9/900
# 6/6 [==============================] - 0s 9ms/step - loss: 1.2497 - accuracy: 0.6193 - val_loss: 1.2239 - val_accuracy: 0.6267
# Epoch 10/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.2104 - accuracy: 0.6201 - val_loss: 1.1862 - val_accuracy: 0.6283
# Epoch 11/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1747 - accuracy: 0.6204 - val_loss: 1.1537 - val_accuracy: 0.6287
# Epoch 12/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1442 - accuracy: 0.6204 - val_loss: 1.1264 - val_accuracy: 0.6287
# Epoch 13/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.1192 - accuracy: 0.6204 - val_loss: 1.1040 - val_accuracy: 0.6287
# Epoch 14/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0988 - accuracy: 0.6204 - val_loss: 1.0859 - val_accuracy: 0.6287
# Epoch 15/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0825 - accuracy: 0.6205 - val_loss: 1.0712 - val_accuracy: 0.6287
# Epoch 16/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0693 - accuracy: 0.6205 - val_loss: 1.0592 - val_accuracy: 0.6287
# Epoch 17/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0586 - accuracy: 0.6206 - val_loss: 1.0495 - val_accuracy: 0.6287
# Epoch 18/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0499 - accuracy: 0.6206 - val_loss: 1.0415 - val_accuracy: 0.6290
# Epoch 19/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0428 - accuracy: 0.6206 - val_loss: 1.0350 - val_accuracy: 0.6290
# Epoch 20/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0370 - accuracy: 0.6206 - val_loss: 1.0295 - val_accuracy: 0.6290
# Epoch 21/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0321 - accuracy: 0.6206 - val_loss: 1.0248 - val_accuracy: 0.6290
# Epoch 22/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0279 - accuracy: 0.6206 - val_loss: 1.0209 - val_accuracy: 0.6290
# Epoch 23/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0242 - accuracy: 0.6206 - val_loss: 1.0175 - val_accuracy: 0.6290
# Epoch 24/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0210 - accuracy: 0.6206 - val_loss: 1.0143 - val_accuracy: 0.6290
# Epoch 25/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0179 - accuracy: 0.6207 - val_loss: 1.0113 - val_accuracy: 0.6290
# Epoch 26/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0149 - accuracy: 0.6208 - val_loss: 1.0077 - val_accuracy: 0.6290
# Epoch 27/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0112 - accuracy: 0.6207 - val_loss: 1.0041 - val_accuracy: 0.6290
# Epoch 28/900
# 6/6 [==============================] - 0s 8ms/step - loss: 1.0079 - accuracy: 0.6208 - val_loss: 1.0012 - val_accuracy: 0.6290
# Epoch 29/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0050 - accuracy: 0.6209 - val_loss: 0.9984 - val_accuracy: 0.6290
# Epoch 30/900
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0019 - accuracy: 0.6209 - val_loss: 0.9950 - val_accuracy: 0.6293
# Epoch 31/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9982 - accuracy: 0.6209 - val_loss: 0.9905 - val_accuracy: 0.6293
# Epoch 32/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9934 - accuracy: 0.6209 - val_loss: 0.9847 - val_accuracy: 0.6293
# Epoch 33/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.9880 - accuracy: 0.6209 - val_loss: 0.9794 - val_accuracy: 0.6293
# Epoch 34/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9829 - accuracy: 0.6209 - val_loss: 0.9743 - val_accuracy: 0.6293
# Epoch 35/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9776 - accuracy: 0.6209 - val_loss: 0.9688 - val_accuracy: 0.6293
# Epoch 36/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9720 - accuracy: 0.6210 - val_loss: 0.9630 - val_accuracy: 0.6293
# Epoch 37/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.9659 - accuracy: 0.6210 - val_loss: 0.9562 - val_accuracy: 0.6293
# Epoch 38/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9589 - accuracy: 0.6210 - val_loss: 0.9489 - val_accuracy: 0.6293
# Epoch 39/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9516 - accuracy: 0.6211 - val_loss: 0.9413 - val_accuracy: 0.6293
# Epoch 40/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9439 - accuracy: 0.6211 - val_loss: 0.9331 - val_accuracy: 0.6293
# Epoch 41/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9362 - accuracy: 0.6211 - val_loss: 0.9247 - val_accuracy: 0.6293
# Epoch 42/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9278 - accuracy: 0.6211 - val_loss: 0.9163 - val_accuracy: 0.6293
# Epoch 43/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9191 - accuracy: 0.6216 - val_loss: 0.9070 - val_accuracy: 0.6313
# Epoch 44/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9098 - accuracy: 0.6229 - val_loss: 0.8972 - val_accuracy: 0.6330
# Epoch 45/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.9001 - accuracy: 0.6249 - val_loss: 0.8868 - val_accuracy: 0.6350
# Epoch 46/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.8893 - accuracy: 0.6292 - val_loss: 0.8744 - val_accuracy: 0.6427
# Epoch 47/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8761 - accuracy: 0.6374 - val_loss: 0.8586 - val_accuracy: 0.6573
# Epoch 48/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8584 - accuracy: 0.6567 - val_loss: 0.8382 - val_accuracy: 0.6767
# Epoch 49/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8385 - accuracy: 0.6737 - val_loss: 0.8195 - val_accuracy: 0.6820
# Epoch 50/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.8206 - accuracy: 0.6741 - val_loss: 0.8041 - val_accuracy: 0.6873
# Epoch 51/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.8060 - accuracy: 0.6834 - val_loss: 0.7904 - val_accuracy: 0.6967
# Epoch 52/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7932 - accuracy: 0.6946 - val_loss: 0.7778 - val_accuracy: 0.6997
# Epoch 53/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7812 - accuracy: 0.6952 - val_loss: 0.7659 - val_accuracy: 0.7110
# Epoch 54/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7695 - accuracy: 0.7045 - val_loss: 0.7543 - val_accuracy: 0.7160
# Epoch 55/900
# 6/6 [==============================] - 0s 10ms/step - loss: 0.7583 - accuracy: 0.7097 - val_loss: 0.7427 - val_accuracy: 0.7197
# Epoch 56/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7475 - accuracy: 0.7150 - val_loss: 0.7322 - val_accuracy: 0.7220
# Epoch 57/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7368 - accuracy: 0.7159 - val_loss: 0.7211 - val_accuracy: 0.7270
# Epoch 58/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.7267 - accuracy: 0.7229 - val_loss: 0.7110 - val_accuracy: 0.7310
# Epoch 59/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7165 - accuracy: 0.7221 - val_loss: 0.7011 - val_accuracy: 0.7330
# Epoch 60/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.7075 - accuracy: 0.7265 - val_loss: 0.6925 - val_accuracy: 0.7400
# Epoch 61/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6990 - accuracy: 0.7328 - val_loss: 0.6848 - val_accuracy: 0.7487
# Epoch 62/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6914 - accuracy: 0.7326 - val_loss: 0.6768 - val_accuracy: 0.7497
# Epoch 63/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6839 - accuracy: 0.7413 - val_loss: 0.6696 - val_accuracy: 0.7510
# Epoch 64/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6769 - accuracy: 0.7374 - val_loss: 0.6629 - val_accuracy: 0.7557
# Epoch 65/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.6702 - accuracy: 0.7406 - val_loss: 0.6566 - val_accuracy: 0.7603
# Epoch 66/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6641 - accuracy: 0.7457 - val_loss: 0.6505 - val_accuracy: 0.7603
# Epoch 67/900
# 6/6 [==============================] - ETA: 0s - loss: 0.6750 - accuracy: 0.74 - 0s 7ms/step - loss: 0.6583 - accuracy: 0.7430 - val_loss: 0.6445 - val_accuracy: 0.7603
# Epoch 68/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6526 - accuracy: 0.7490 - val_loss: 0.6395 - val_accuracy: 0.7637
# Epoch 69/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6474 - accuracy: 0.7436 - val_loss: 0.6338 - val_accuracy: 0.7677
# Epoch 70/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6423 - accuracy: 0.7571 - val_loss: 0.6295 - val_accuracy: 0.7633
# Epoch 71/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6378 - accuracy: 0.7449 - val_loss: 0.6243 - val_accuracy: 0.7697
# Epoch 72/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6331 - accuracy: 0.7595 - val_loss: 0.6204 - val_accuracy: 0.7663
# Epoch 73/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6284 - accuracy: 0.7506 - val_loss: 0.6155 - val_accuracy: 0.7700
# Epoch 74/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6241 - accuracy: 0.7556 - val_loss: 0.6115 - val_accuracy: 0.7693
# Epoch 75/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6199 - accuracy: 0.7544 - val_loss: 0.6079 - val_accuracy: 0.7790
# Epoch 76/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6162 - accuracy: 0.7654 - val_loss: 0.6043 - val_accuracy: 0.7687
# Epoch 77/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6120 - accuracy: 0.7566 - val_loss: 0.6008 - val_accuracy: 0.7820
# Epoch 78/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6084 - accuracy: 0.7661 - val_loss: 0.5974 - val_accuracy: 0.7773
# Epoch 79/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.6052 - accuracy: 0.7607 - val_loss: 0.5940 - val_accuracy: 0.7833
# Epoch 80/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.6017 - accuracy: 0.7697 - val_loss: 0.5909 - val_accuracy: 0.7820
# Epoch 81/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5987 - accuracy: 0.7635 - val_loss: 0.5878 - val_accuracy: 0.7853
# Epoch 82/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5957 - accuracy: 0.7714 - val_loss: 0.5852 - val_accuracy: 0.7810
# Epoch 83/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5929 - accuracy: 0.7661 - val_loss: 0.5824 - val_accuracy: 0.7863
# Epoch 84/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5899 - accuracy: 0.7714 - val_loss: 0.5796 - val_accuracy: 0.7840
# Epoch 85/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5870 - accuracy: 0.7723 - val_loss: 0.5772 - val_accuracy: 0.7883
# Epoch 86/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5846 - accuracy: 0.7729 - val_loss: 0.5747 - val_accuracy: 0.7883
# Epoch 87/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5823 - accuracy: 0.7784 - val_loss: 0.5725 - val_accuracy: 0.7893
# Epoch 88/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5797 - accuracy: 0.7718 - val_loss: 0.5702 - val_accuracy: 0.7900
# Epoch 89/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5777 - accuracy: 0.7791 - val_loss: 0.5679 - val_accuracy: 0.7910
# Epoch 90/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5758 - accuracy: 0.7729 - val_loss: 0.5659 - val_accuracy: 0.7947
# Epoch 91/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5731 - accuracy: 0.7818 - val_loss: 0.5642 - val_accuracy: 0.7930
# Epoch 92/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5709 - accuracy: 0.7789 - val_loss: 0.5619 - val_accuracy: 0.7943
# Epoch 93/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5690 - accuracy: 0.7808 - val_loss: 0.5603 - val_accuracy: 0.7953
# Epoch 94/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5670 - accuracy: 0.7818 - val_loss: 0.5584 - val_accuracy: 0.7967
# Epoch 95/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5651 - accuracy: 0.7835 - val_loss: 0.5566 - val_accuracy: 0.7970
# Epoch 96/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5635 - accuracy: 0.7841 - val_loss: 0.5554 - val_accuracy: 0.7970
# Epoch 97/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5618 - accuracy: 0.7845 - val_loss: 0.5534 - val_accuracy: 0.7983
# Epoch 98/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5601 - accuracy: 0.7852 - val_loss: 0.5523 - val_accuracy: 0.8017
# Epoch 99/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5584 - accuracy: 0.7861 - val_loss: 0.5503 - val_accuracy: 0.8000
# Epoch 100/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5571 - accuracy: 0.7867 - val_loss: 0.5491 - val_accuracy: 0.7997
# Epoch 101/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5554 - accuracy: 0.7863 - val_loss: 0.5473 - val_accuracy: 0.8007
# Epoch 102/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5540 - accuracy: 0.7876 - val_loss: 0.5463 - val_accuracy: 0.8010
# Epoch 103/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5529 - accuracy: 0.7861 - val_loss: 0.5449 - val_accuracy: 0.8013
# Epoch 104/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5517 - accuracy: 0.7908 - val_loss: 0.5441 - val_accuracy: 0.7997
# Epoch 105/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5502 - accuracy: 0.7861 - val_loss: 0.5430 - val_accuracy: 0.8053
# Epoch 106/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5491 - accuracy: 0.7926 - val_loss: 0.5418 - val_accuracy: 0.8010
# Epoch 107/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5475 - accuracy: 0.7879 - val_loss: 0.5405 - val_accuracy: 0.8067
# Epoch 108/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5468 - accuracy: 0.7949 - val_loss: 0.5400 - val_accuracy: 0.8013
# Epoch 109/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5454 - accuracy: 0.7884 - val_loss: 0.5382 - val_accuracy: 0.8043
# Epoch 110/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5443 - accuracy: 0.7914 - val_loss: 0.5372 - val_accuracy: 0.8047
# Epoch 111/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5430 - accuracy: 0.7907 - val_loss: 0.5361 - val_accuracy: 0.8053
# Epoch 112/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5420 - accuracy: 0.7916 - val_loss: 0.5353 - val_accuracy: 0.8053
# Epoch 113/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5411 - accuracy: 0.7921 - val_loss: 0.5345 - val_accuracy: 0.8053
# Epoch 114/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5402 - accuracy: 0.7912 - val_loss: 0.5333 - val_accuracy: 0.8070
# Epoch 115/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5393 - accuracy: 0.7925 - val_loss: 0.5326 - val_accuracy: 0.8060
# Epoch 116/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5384 - accuracy: 0.7943 - val_loss: 0.5316 - val_accuracy: 0.8050
# Epoch 117/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5380 - accuracy: 0.7929 - val_loss: 0.5310 - val_accuracy: 0.8087
# Epoch 118/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5366 - accuracy: 0.7953 - val_loss: 0.5304 - val_accuracy: 0.8043
# Epoch 119/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5362 - accuracy: 0.7937 - val_loss: 0.5296 - val_accuracy: 0.8097
# Epoch 120/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5353 - accuracy: 0.7944 - val_loss: 0.5285 - val_accuracy: 0.8067
# Epoch 121/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5344 - accuracy: 0.7945 - val_loss: 0.5282 - val_accuracy: 0.8107
# Epoch 122/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5337 - accuracy: 0.7949 - val_loss: 0.5273 - val_accuracy: 0.8083
# Epoch 123/900
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5328 - accuracy: 0.7984 - val_loss: 0.5269 - val_accuracy: 0.8083
# Epoch 124/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5324 - accuracy: 0.7931 - val_loss: 0.5257 - val_accuracy: 0.8100
# Epoch 125/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5313 - accuracy: 0.7974 - val_loss: 0.5254 - val_accuracy: 0.8103
# Epoch 126/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5308 - accuracy: 0.7958 - val_loss: 0.5246 - val_accuracy: 0.8117
# Epoch 127/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5301 - accuracy: 0.7978 - val_loss: 0.5244 - val_accuracy: 0.8103
# Epoch 128/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5299 - accuracy: 0.7958 - val_loss: 0.5236 - val_accuracy: 0.8123
# Epoch 129/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5292 - accuracy: 0.7969 - val_loss: 0.5228 - val_accuracy: 0.8120
# Epoch 130/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5282 - accuracy: 0.7988 - val_loss: 0.5225 - val_accuracy: 0.8127
# Epoch 131/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5277 - accuracy: 0.7974 - val_loss: 0.5219 - val_accuracy: 0.8130
# Epoch 132/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5274 - accuracy: 0.7974 - val_loss: 0.5211 - val_accuracy: 0.8123
# Epoch 133/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5267 - accuracy: 0.8000 - val_loss: 0.5207 - val_accuracy: 0.8110
# Epoch 134/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5260 - accuracy: 0.7985 - val_loss: 0.5203 - val_accuracy: 0.8117
# Epoch 135/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5255 - accuracy: 0.7982 - val_loss: 0.5197 - val_accuracy: 0.8160
# Epoch 136/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5249 - accuracy: 0.8000 - val_loss: 0.5193 - val_accuracy: 0.8120
# Epoch 137/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5248 - accuracy: 0.7986 - val_loss: 0.5189 - val_accuracy: 0.8110
# Epoch 138/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5245 - accuracy: 0.7954 - val_loss: 0.5187 - val_accuracy: 0.8153
# Epoch 139/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5240 - accuracy: 0.8025 - val_loss: 0.5192 - val_accuracy: 0.8077
# Epoch 140/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5237 - accuracy: 0.7952 - val_loss: 0.5181 - val_accuracy: 0.8160
# Epoch 141/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5230 - accuracy: 0.8021 - val_loss: 0.5187 - val_accuracy: 0.8070
# Epoch 142/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5225 - accuracy: 0.7961 - val_loss: 0.5178 - val_accuracy: 0.8160
# Epoch 143/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5222 - accuracy: 0.8007 - val_loss: 0.5174 - val_accuracy: 0.8080
# Epoch 144/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5220 - accuracy: 0.8000 - val_loss: 0.5163 - val_accuracy: 0.8163
# Epoch 145/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5212 - accuracy: 0.7993 - val_loss: 0.5156 - val_accuracy: 0.8127
# Epoch 146/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5206 - accuracy: 0.8001 - val_loss: 0.5153 - val_accuracy: 0.8140
# Epoch 147/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5202 - accuracy: 0.7979 - val_loss: 0.5150 - val_accuracy: 0.8147
# Epoch 148/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5198 - accuracy: 0.8019 - val_loss: 0.5145 - val_accuracy: 0.8127
# Epoch 149/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5194 - accuracy: 0.8012 - val_loss: 0.5141 - val_accuracy: 0.8127
# Epoch 150/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5191 - accuracy: 0.7980 - val_loss: 0.5137 - val_accuracy: 0.8147
# Epoch 151/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5186 - accuracy: 0.7998 - val_loss: 0.5136 - val_accuracy: 0.8123
# Epoch 152/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5186 - accuracy: 0.8026 - val_loss: 0.5134 - val_accuracy: 0.8113
# Epoch 153/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5182 - accuracy: 0.7976 - val_loss: 0.5129 - val_accuracy: 0.8160
# Epoch 154/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5176 - accuracy: 0.8025 - val_loss: 0.5133 - val_accuracy: 0.8100
# Epoch 155/900
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5176 - accuracy: 0.7984 - val_loss: 0.5129 - val_accuracy: 0.8160
# Epoch 156/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5169 - accuracy: 0.8027 - val_loss: 0.5123 - val_accuracy: 0.8123
# Epoch 157/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5168 - accuracy: 0.7994 - val_loss: 0.5115 - val_accuracy: 0.8170
# Epoch 158/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5166 - accuracy: 0.8014 - val_loss: 0.5118 - val_accuracy: 0.8140
# Epoch 159/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5161 - accuracy: 0.8003 - val_loss: 0.5112 - val_accuracy: 0.8143
# Epoch 160/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5157 - accuracy: 0.8021 - val_loss: 0.5111 - val_accuracy: 0.8140
# Epoch 161/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5157 - accuracy: 0.8016 - val_loss: 0.5106 - val_accuracy: 0.8110
# Epoch 162/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5152 - accuracy: 0.8009 - val_loss: 0.5103 - val_accuracy: 0.8150
# Epoch 163/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5148 - accuracy: 0.8011 - val_loss: 0.5099 - val_accuracy: 0.8147
# Epoch 164/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5144 - accuracy: 0.8019 - val_loss: 0.5100 - val_accuracy: 0.8153
# Epoch 165/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5142 - accuracy: 0.8024 - val_loss: 0.5094 - val_accuracy: 0.8120
# Epoch 166/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5139 - accuracy: 0.8029 - val_loss: 0.5091 - val_accuracy: 0.8170
# Epoch 167/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5136 - accuracy: 0.8008 - val_loss: 0.5091 - val_accuracy: 0.8117
# Epoch 168/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5134 - accuracy: 0.8035 - val_loss: 0.5088 - val_accuracy: 0.8143
# Epoch 169/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5130 - accuracy: 0.8019 - val_loss: 0.5084 - val_accuracy: 0.8157
# Epoch 170/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5130 - accuracy: 0.8036 - val_loss: 0.5081 - val_accuracy: 0.8143
# Epoch 171/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5129 - accuracy: 0.7994 - val_loss: 0.5081 - val_accuracy: 0.8153
# Epoch 172/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5127 - accuracy: 0.8053 - val_loss: 0.5078 - val_accuracy: 0.8127
# Epoch 173/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5122 - accuracy: 0.8008 - val_loss: 0.5074 - val_accuracy: 0.8123
# Epoch 174/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5117 - accuracy: 0.8036 - val_loss: 0.5074 - val_accuracy: 0.8170
# Epoch 175/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5115 - accuracy: 0.8034 - val_loss: 0.5074 - val_accuracy: 0.8140
# Epoch 176/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5114 - accuracy: 0.8015 - val_loss: 0.5072 - val_accuracy: 0.8140
# Epoch 177/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5112 - accuracy: 0.8041 - val_loss: 0.5066 - val_accuracy: 0.8110
# Epoch 178/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5109 - accuracy: 0.8024 - val_loss: 0.5062 - val_accuracy: 0.8150
# Epoch 179/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5106 - accuracy: 0.8010 - val_loss: 0.5063 - val_accuracy: 0.8137
# Epoch 180/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5105 - accuracy: 0.8050 - val_loss: 0.5062 - val_accuracy: 0.8113
# Epoch 181/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5101 - accuracy: 0.8009 - val_loss: 0.5057 - val_accuracy: 0.8153
# Epoch 182/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5102 - accuracy: 0.8044 - val_loss: 0.5054 - val_accuracy: 0.8127
# Epoch 183/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5100 - accuracy: 0.8039 - val_loss: 0.5054 - val_accuracy: 0.8133
# Epoch 184/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5092 - accuracy: 0.8022 - val_loss: 0.5052 - val_accuracy: 0.8140
# Epoch 185/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5091 - accuracy: 0.8032 - val_loss: 0.5047 - val_accuracy: 0.8150
# Epoch 186/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5088 - accuracy: 0.8029 - val_loss: 0.5047 - val_accuracy: 0.8143
# Epoch 187/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5091 - accuracy: 0.8057 - val_loss: 0.5050 - val_accuracy: 0.8103
# Epoch 188/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5091 - accuracy: 0.7999 - val_loss: 0.5051 - val_accuracy: 0.8160
# Epoch 189/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5086 - accuracy: 0.8051 - val_loss: 0.5039 - val_accuracy: 0.8107
# Epoch 190/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5081 - accuracy: 0.8029 - val_loss: 0.5034 - val_accuracy: 0.8167
# Epoch 191/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5079 - accuracy: 0.8047 - val_loss: 0.5029 - val_accuracy: 0.8153
# Epoch 192/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5077 - accuracy: 0.8044 - val_loss: 0.5025 - val_accuracy: 0.8143
# Epoch 193/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5072 - accuracy: 0.8054 - val_loss: 0.5024 - val_accuracy: 0.8140
# Epoch 194/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5069 - accuracy: 0.8039 - val_loss: 0.5021 - val_accuracy: 0.8160
# Epoch 195/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5067 - accuracy: 0.8033 - val_loss: 0.5017 - val_accuracy: 0.8160
# Epoch 196/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5068 - accuracy: 0.8056 - val_loss: 0.5015 - val_accuracy: 0.8157
# Epoch 197/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5066 - accuracy: 0.8031 - val_loss: 0.5013 - val_accuracy: 0.8153
# Epoch 198/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5061 - accuracy: 0.8070 - val_loss: 0.5014 - val_accuracy: 0.8147
# Epoch 199/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5057 - accuracy: 0.8032 - val_loss: 0.5009 - val_accuracy: 0.8143
# Epoch 200/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5056 - accuracy: 0.8047 - val_loss: 0.5003 - val_accuracy: 0.8157
# Epoch 201/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5054 - accuracy: 0.8036 - val_loss: 0.5002 - val_accuracy: 0.8160
# Epoch 202/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5050 - accuracy: 0.8047 - val_loss: 0.5002 - val_accuracy: 0.8167
# Epoch 203/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5049 - accuracy: 0.8065 - val_loss: 0.5001 - val_accuracy: 0.8147
# Epoch 204/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5048 - accuracy: 0.8044 - val_loss: 0.5000 - val_accuracy: 0.8160
# Epoch 205/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5044 - accuracy: 0.8054 - val_loss: 0.4994 - val_accuracy: 0.8150
# Epoch 206/900
# 6/6 [==============================] - ETA: 0s - loss: 0.5032 - accuracy: 0.81 - 0s 7ms/step - loss: 0.5044 - accuracy: 0.8058 - val_loss: 0.4992 - val_accuracy: 0.8153
# Epoch 207/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5042 - accuracy: 0.8025 - val_loss: 0.4995 - val_accuracy: 0.8160
# Epoch 208/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5040 - accuracy: 0.8061 - val_loss: 0.4991 - val_accuracy: 0.8147
# Epoch 209/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5037 - accuracy: 0.8032 - val_loss: 0.4986 - val_accuracy: 0.8163
# Epoch 210/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5035 - accuracy: 0.8076 - val_loss: 0.4987 - val_accuracy: 0.8137
# Epoch 211/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5033 - accuracy: 0.8038 - val_loss: 0.4984 - val_accuracy: 0.8150
# Epoch 212/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5030 - accuracy: 0.8061 - val_loss: 0.4981 - val_accuracy: 0.8143
# Epoch 213/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5030 - accuracy: 0.8047 - val_loss: 0.4983 - val_accuracy: 0.8157
# Epoch 214/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5031 - accuracy: 0.8025 - val_loss: 0.4983 - val_accuracy: 0.8150
# Epoch 215/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5027 - accuracy: 0.8086 - val_loss: 0.4974 - val_accuracy: 0.8153
# Epoch 216/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5023 - accuracy: 0.8034 - val_loss: 0.4970 - val_accuracy: 0.8167
# Epoch 217/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5023 - accuracy: 0.8061 - val_loss: 0.4976 - val_accuracy: 0.8137
# Epoch 218/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5022 - accuracy: 0.8020 - val_loss: 0.4976 - val_accuracy: 0.8147
# Epoch 219/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5021 - accuracy: 0.8085 - val_loss: 0.4972 - val_accuracy: 0.8133
# Epoch 220/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5018 - accuracy: 0.8030 - val_loss: 0.4980 - val_accuracy: 0.8157
# Epoch 221/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5019 - accuracy: 0.8069 - val_loss: 0.4969 - val_accuracy: 0.8130
# Epoch 222/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.5015 - accuracy: 0.8043 - val_loss: 0.4966 - val_accuracy: 0.8163
# Epoch 223/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5009 - accuracy: 0.8066 - val_loss: 0.4961 - val_accuracy: 0.8127
# Epoch 224/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5012 - accuracy: 0.8054 - val_loss: 0.4959 - val_accuracy: 0.8143
# Epoch 225/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5008 - accuracy: 0.8041 - val_loss: 0.4960 - val_accuracy: 0.8143
# Epoch 226/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5003 - accuracy: 0.8051 - val_loss: 0.4954 - val_accuracy: 0.8130
# Epoch 227/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5002 - accuracy: 0.8062 - val_loss: 0.4955 - val_accuracy: 0.8147
# Epoch 228/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.5001 - accuracy: 0.8052 - val_loss: 0.4952 - val_accuracy: 0.8133
# Epoch 229/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4999 - accuracy: 0.8067 - val_loss: 0.4950 - val_accuracy: 0.8157
# Epoch 230/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4994 - accuracy: 0.8064 - val_loss: 0.4948 - val_accuracy: 0.8110
# Epoch 231/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4995 - accuracy: 0.8036 - val_loss: 0.4949 - val_accuracy: 0.8133
# Epoch 232/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4993 - accuracy: 0.8084 - val_loss: 0.4942 - val_accuracy: 0.8153
# Epoch 233/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4993 - accuracy: 0.8046 - val_loss: 0.4940 - val_accuracy: 0.8157
# Epoch 234/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4991 - accuracy: 0.8055 - val_loss: 0.4944 - val_accuracy: 0.8157
# Epoch 235/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4991 - accuracy: 0.8089 - val_loss: 0.4944 - val_accuracy: 0.8110
# Epoch 236/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4992 - accuracy: 0.8029 - val_loss: 0.4947 - val_accuracy: 0.8137
# Epoch 237/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4985 - accuracy: 0.8084 - val_loss: 0.4937 - val_accuracy: 0.8123
# Epoch 238/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4982 - accuracy: 0.8050 - val_loss: 0.4933 - val_accuracy: 0.8167
# Epoch 239/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4982 - accuracy: 0.8069 - val_loss: 0.4931 - val_accuracy: 0.8133
# Epoch 240/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4978 - accuracy: 0.8076 - val_loss: 0.4931 - val_accuracy: 0.8140
# Epoch 241/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4975 - accuracy: 0.8056 - val_loss: 0.4930 - val_accuracy: 0.8140
# Epoch 242/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4975 - accuracy: 0.8081 - val_loss: 0.4923 - val_accuracy: 0.8140
# Epoch 243/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4973 - accuracy: 0.8058 - val_loss: 0.4924 - val_accuracy: 0.8150
# Epoch 244/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4969 - accuracy: 0.8068 - val_loss: 0.4926 - val_accuracy: 0.8130
# Epoch 245/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4968 - accuracy: 0.8075 - val_loss: 0.4920 - val_accuracy: 0.8163
# Epoch 246/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4966 - accuracy: 0.8086 - val_loss: 0.4919 - val_accuracy: 0.8143
# Epoch 247/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4968 - accuracy: 0.8039 - val_loss: 0.4925 - val_accuracy: 0.8167
# Epoch 248/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4969 - accuracy: 0.8086 - val_loss: 0.4922 - val_accuracy: 0.8133
# Epoch 249/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4970 - accuracy: 0.8073 - val_loss: 0.4918 - val_accuracy: 0.8140
# Epoch 250/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4962 - accuracy: 0.8033 - val_loss: 0.4914 - val_accuracy: 0.8133
# Epoch 251/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4963 - accuracy: 0.8097 - val_loss: 0.4913 - val_accuracy: 0.8127
# Epoch 252/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4964 - accuracy: 0.8021 - val_loss: 0.4916 - val_accuracy: 0.8163
# Epoch 253/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4963 - accuracy: 0.8109 - val_loss: 0.4913 - val_accuracy: 0.8140
# Epoch 254/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4958 - accuracy: 0.8045 - val_loss: 0.4913 - val_accuracy: 0.8140
# Epoch 255/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4957 - accuracy: 0.8078 - val_loss: 0.4903 - val_accuracy: 0.8130
# Epoch 256/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4955 - accuracy: 0.8086 - val_loss: 0.4900 - val_accuracy: 0.8140
# Epoch 257/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4953 - accuracy: 0.8041 - val_loss: 0.4906 - val_accuracy: 0.8167
# Epoch 258/900
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4949 - accuracy: 0.8107 - val_loss: 0.4903 - val_accuracy: 0.8120
# Epoch 259/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4947 - accuracy: 0.8051 - val_loss: 0.4901 - val_accuracy: 0.8153
# Epoch 260/900
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4943 - accuracy: 0.8092 - val_loss: 0.4894 - val_accuracy: 0.8127
# Epoch 261/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4943 - accuracy: 0.8068 - val_loss: 0.4900 - val_accuracy: 0.8153
# Epoch 262/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4941 - accuracy: 0.8086 - val_loss: 0.4895 - val_accuracy: 0.8120
# Epoch 263/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4940 - accuracy: 0.8096 - val_loss: 0.4893 - val_accuracy: 0.8133
# Epoch 264/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4940 - accuracy: 0.8046 - val_loss: 0.4892 - val_accuracy: 0.8163
# Epoch 265/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4936 - accuracy: 0.8104 - val_loss: 0.4887 - val_accuracy: 0.8137
# Epoch 266/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4938 - accuracy: 0.8072 - val_loss: 0.4891 - val_accuracy: 0.8153
# Epoch 267/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4930 - accuracy: 0.8098 - val_loss: 0.4885 - val_accuracy: 0.8120
# Epoch 268/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4930 - accuracy: 0.8071 - val_loss: 0.4884 - val_accuracy: 0.8147
# Epoch 269/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4927 - accuracy: 0.8090 - val_loss: 0.4883 - val_accuracy: 0.8133
# Epoch 270/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4927 - accuracy: 0.8081 - val_loss: 0.4882 - val_accuracy: 0.8120
# Epoch 271/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4924 - accuracy: 0.8084 - val_loss: 0.4878 - val_accuracy: 0.8140
# Epoch 272/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4923 - accuracy: 0.8090 - val_loss: 0.4877 - val_accuracy: 0.8133
# Epoch 273/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4922 - accuracy: 0.8096 - val_loss: 0.4880 - val_accuracy: 0.8143
# Epoch 274/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4922 - accuracy: 0.8084 - val_loss: 0.4875 - val_accuracy: 0.8140
# Epoch 275/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4925 - accuracy: 0.8079 - val_loss: 0.4877 - val_accuracy: 0.8157
# Epoch 276/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4922 - accuracy: 0.8077 - val_loss: 0.4871 - val_accuracy: 0.8120
# Epoch 277/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4919 - accuracy: 0.8101 - val_loss: 0.4875 - val_accuracy: 0.8160
# Epoch 278/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4916 - accuracy: 0.8064 - val_loss: 0.4867 - val_accuracy: 0.8130
# Epoch 279/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4914 - accuracy: 0.8102 - val_loss: 0.4870 - val_accuracy: 0.8163
# Epoch 280/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4912 - accuracy: 0.8071 - val_loss: 0.4867 - val_accuracy: 0.8117
# Epoch 281/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4908 - accuracy: 0.8071 - val_loss: 0.4865 - val_accuracy: 0.8160
# Epoch 282/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4910 - accuracy: 0.8088 - val_loss: 0.4864 - val_accuracy: 0.8153
# Epoch 283/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4905 - accuracy: 0.8106 - val_loss: 0.4859 - val_accuracy: 0.8123
# Epoch 284/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4902 - accuracy: 0.8082 - val_loss: 0.4859 - val_accuracy: 0.8160
# Epoch 285/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4901 - accuracy: 0.8116 - val_loss: 0.4861 - val_accuracy: 0.8133
# Epoch 286/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4902 - accuracy: 0.8054 - val_loss: 0.4861 - val_accuracy: 0.8160
# Epoch 287/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4900 - accuracy: 0.8114 - val_loss: 0.4851 - val_accuracy: 0.8133
# Epoch 288/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4896 - accuracy: 0.8096 - val_loss: 0.4855 - val_accuracy: 0.8150
# Epoch 289/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4898 - accuracy: 0.8084 - val_loss: 0.4853 - val_accuracy: 0.8137
# Epoch 290/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4894 - accuracy: 0.8114 - val_loss: 0.4852 - val_accuracy: 0.8147
# Epoch 291/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4894 - accuracy: 0.8098 - val_loss: 0.4848 - val_accuracy: 0.8147
# Epoch 292/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4891 - accuracy: 0.8083 - val_loss: 0.4851 - val_accuracy: 0.8157
# Epoch 293/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4891 - accuracy: 0.8133 - val_loss: 0.4844 - val_accuracy: 0.8133
# Epoch 294/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4888 - accuracy: 0.8079 - val_loss: 0.4847 - val_accuracy: 0.8147
# Epoch 295/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4886 - accuracy: 0.8116 - val_loss: 0.4843 - val_accuracy: 0.8147
# Epoch 296/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4884 - accuracy: 0.8104 - val_loss: 0.4841 - val_accuracy: 0.8153
# Epoch 297/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4886 - accuracy: 0.8090 - val_loss: 0.4841 - val_accuracy: 0.8123
# Epoch 298/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4881 - accuracy: 0.8101 - val_loss: 0.4839 - val_accuracy: 0.8177
# Epoch 299/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4879 - accuracy: 0.8098 - val_loss: 0.4833 - val_accuracy: 0.8130
# Epoch 300/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4877 - accuracy: 0.8107 - val_loss: 0.4835 - val_accuracy: 0.8160
# Epoch 301/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4877 - accuracy: 0.8100 - val_loss: 0.4838 - val_accuracy: 0.8140
# Epoch 302/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4876 - accuracy: 0.8120 - val_loss: 0.4830 - val_accuracy: 0.8140
# Epoch 303/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4880 - accuracy: 0.8071 - val_loss: 0.4828 - val_accuracy: 0.8157
# Epoch 304/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4873 - accuracy: 0.8086 - val_loss: 0.4829 - val_accuracy: 0.8147
# Epoch 305/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4870 - accuracy: 0.8121 - val_loss: 0.4830 - val_accuracy: 0.8163
# Epoch 306/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4870 - accuracy: 0.8103 - val_loss: 0.4824 - val_accuracy: 0.8160
# Epoch 307/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4867 - accuracy: 0.8108 - val_loss: 0.4822 - val_accuracy: 0.8163
# Epoch 308/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4863 - accuracy: 0.8116 - val_loss: 0.4826 - val_accuracy: 0.8147
# Epoch 309/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4866 - accuracy: 0.8118 - val_loss: 0.4827 - val_accuracy: 0.8127
# Epoch 310/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4868 - accuracy: 0.8107 - val_loss: 0.4819 - val_accuracy: 0.8153
# Epoch 311/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4863 - accuracy: 0.8082 - val_loss: 0.4815 - val_accuracy: 0.8173
# Epoch 312/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4859 - accuracy: 0.8121 - val_loss: 0.4818 - val_accuracy: 0.8153
# Epoch 313/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4858 - accuracy: 0.8124 - val_loss: 0.4813 - val_accuracy: 0.8143
# Epoch 314/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4858 - accuracy: 0.8092 - val_loss: 0.4816 - val_accuracy: 0.8170
# Epoch 315/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4858 - accuracy: 0.8132 - val_loss: 0.4816 - val_accuracy: 0.8147
# Epoch 316/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4854 - accuracy: 0.8075 - val_loss: 0.4815 - val_accuracy: 0.8153
# Epoch 317/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4856 - accuracy: 0.8116 - val_loss: 0.4811 - val_accuracy: 0.8160
# Epoch 318/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4856 - accuracy: 0.8092 - val_loss: 0.4817 - val_accuracy: 0.8167
# Epoch 319/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4854 - accuracy: 0.8121 - val_loss: 0.4812 - val_accuracy: 0.8113
# Epoch 320/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4853 - accuracy: 0.8083 - val_loss: 0.4815 - val_accuracy: 0.8173
# Epoch 321/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4851 - accuracy: 0.8102 - val_loss: 0.4800 - val_accuracy: 0.8147
# Epoch 322/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4846 - accuracy: 0.8121 - val_loss: 0.4803 - val_accuracy: 0.8167
# Epoch 323/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4842 - accuracy: 0.8109 - val_loss: 0.4802 - val_accuracy: 0.8133
# Epoch 324/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4842 - accuracy: 0.8104 - val_loss: 0.4801 - val_accuracy: 0.8167
# Epoch 325/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4841 - accuracy: 0.8126 - val_loss: 0.4795 - val_accuracy: 0.8167
# Epoch 326/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4838 - accuracy: 0.8101 - val_loss: 0.4795 - val_accuracy: 0.8177
# Epoch 327/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4838 - accuracy: 0.8132 - val_loss: 0.4798 - val_accuracy: 0.8163
# Epoch 328/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4834 - accuracy: 0.8115 - val_loss: 0.4793 - val_accuracy: 0.8143
# Epoch 329/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4836 - accuracy: 0.8119 - val_loss: 0.4792 - val_accuracy: 0.8190
# Epoch 330/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4836 - accuracy: 0.8073 - val_loss: 0.4792 - val_accuracy: 0.8173
# Epoch 331/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4835 - accuracy: 0.8128 - val_loss: 0.4788 - val_accuracy: 0.8153
# Epoch 332/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4830 - accuracy: 0.8093 - val_loss: 0.4789 - val_accuracy: 0.8153
# Epoch 333/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4827 - accuracy: 0.8125 - val_loss: 0.4783 - val_accuracy: 0.8177
# Epoch 334/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4828 - accuracy: 0.8094 - val_loss: 0.4784 - val_accuracy: 0.8177
# Epoch 335/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4829 - accuracy: 0.8134 - val_loss: 0.4784 - val_accuracy: 0.8133
# Epoch 336/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4828 - accuracy: 0.8066 - val_loss: 0.4789 - val_accuracy: 0.8177
# Epoch 337/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4830 - accuracy: 0.8135 - val_loss: 0.4781 - val_accuracy: 0.8160
# Epoch 338/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4827 - accuracy: 0.8080 - val_loss: 0.4781 - val_accuracy: 0.8147
# Epoch 339/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4821 - accuracy: 0.8124 - val_loss: 0.4780 - val_accuracy: 0.8180
# Epoch 340/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4818 - accuracy: 0.8111 - val_loss: 0.4780 - val_accuracy: 0.8163
# Epoch 341/900
# ...
# Epoch 789/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4507 - accuracy: 0.8172 - val_loss: 0.4471 - val_accuracy: 0.8220
# Epoch 790/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4509 - accuracy: 0.8169 - val_loss: 0.4463 - val_accuracy: 0.8230
# Epoch 791/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4508 - accuracy: 0.8171 - val_loss: 0.4466 - val_accuracy: 0.8220
# Epoch 792/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4511 - accuracy: 0.8166 - val_loss: 0.4469 - val_accuracy: 0.8217
# Epoch 793/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4507 - accuracy: 0.8164 - val_loss: 0.4463 - val_accuracy: 0.8230
# Epoch 794/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4507 - accuracy: 0.8164 - val_loss: 0.4462 - val_accuracy: 0.8233
# Epoch 795/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4507 - accuracy: 0.8162 - val_loss: 0.4472 - val_accuracy: 0.8203
# Epoch 796/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4508 - accuracy: 0.8166 - val_loss: 0.4466 - val_accuracy: 0.8233
# Epoch 797/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4508 - accuracy: 0.8155 - val_loss: 0.4469 - val_accuracy: 0.8207
# Epoch 798/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4508 - accuracy: 0.8153 - val_loss: 0.4473 - val_accuracy: 0.8227
# Epoch 799/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4510 - accuracy: 0.8156 - val_loss: 0.4465 - val_accuracy: 0.8223
# Epoch 800/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4506 - accuracy: 0.8168 - val_loss: 0.4461 - val_accuracy: 0.8233
# Epoch 801/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4508 - accuracy: 0.8160 - val_loss: 0.4469 - val_accuracy: 0.8223
# Epoch 802/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4510 - accuracy: 0.8164 - val_loss: 0.4464 - val_accuracy: 0.8237
# Epoch 803/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4505 - accuracy: 0.8168 - val_loss: 0.4464 - val_accuracy: 0.8227
# Epoch 804/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4507 - accuracy: 0.8158 - val_loss: 0.4466 - val_accuracy: 0.8240
# Epoch 805/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4506 - accuracy: 0.8173 - val_loss: 0.4462 - val_accuracy: 0.8223
# Epoch 806/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4504 - accuracy: 0.8173 - val_loss: 0.4461 - val_accuracy: 0.8230
# Epoch 807/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.8166 - val_loss: 0.4460 - val_accuracy: 0.8223
# Epoch 808/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.8164 - val_loss: 0.4470 - val_accuracy: 0.8213
# Epoch 809/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4504 - accuracy: 0.8164 - val_loss: 0.4461 - val_accuracy: 0.8227
# Epoch 810/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4505 - accuracy: 0.8172 - val_loss: 0.4458 - val_accuracy: 0.8237
# Epoch 811/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.8171 - val_loss: 0.4465 - val_accuracy: 0.8223
# Epoch 812/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4504 - accuracy: 0.8170 - val_loss: 0.4462 - val_accuracy: 0.8227
# Epoch 813/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4501 - accuracy: 0.8173 - val_loss: 0.4460 - val_accuracy: 0.8240
# Epoch 814/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4506 - accuracy: 0.8168 - val_loss: 0.4460 - val_accuracy: 0.8230
# Epoch 815/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4504 - accuracy: 0.8167 - val_loss: 0.4463 - val_accuracy: 0.8217
# Epoch 816/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4508 - accuracy: 0.8157 - val_loss: 0.4464 - val_accuracy: 0.8240
# Epoch 817/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4506 - accuracy: 0.8168 - val_loss: 0.4466 - val_accuracy: 0.8203
# Epoch 818/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4500 - accuracy: 0.8169 - val_loss: 0.4468 - val_accuracy: 0.8230
# Epoch 819/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4506 - accuracy: 0.8170 - val_loss: 0.4464 - val_accuracy: 0.8210
# Epoch 820/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4505 - accuracy: 0.8166 - val_loss: 0.4466 - val_accuracy: 0.8230
# Epoch 821/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4501 - accuracy: 0.8161 - val_loss: 0.4458 - val_accuracy: 0.8230
# Epoch 822/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.8168 - val_loss: 0.4458 - val_accuracy: 0.8230
# Epoch 823/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4501 - accuracy: 0.8171 - val_loss: 0.4465 - val_accuracy: 0.8230
# Epoch 824/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.8166 - val_loss: 0.4456 - val_accuracy: 0.8233
# Epoch 825/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4497 - accuracy: 0.8172 - val_loss: 0.4457 - val_accuracy: 0.8230
# Epoch 826/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4500 - accuracy: 0.8166 - val_loss: 0.4454 - val_accuracy: 0.8230
# Epoch 827/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4497 - accuracy: 0.8169 - val_loss: 0.4460 - val_accuracy: 0.8220
# Epoch 828/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4499 - accuracy: 0.8170 - val_loss: 0.4457 - val_accuracy: 0.8247
# Epoch 829/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4500 - accuracy: 0.8169 - val_loss: 0.4455 - val_accuracy: 0.8233
# Epoch 830/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4497 - accuracy: 0.8172 - val_loss: 0.4460 - val_accuracy: 0.8227
# Epoch 831/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4500 - accuracy: 0.8166 - val_loss: 0.4457 - val_accuracy: 0.8223
# Epoch 832/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4497 - accuracy: 0.8166 - val_loss: 0.4455 - val_accuracy: 0.8233
# Epoch 833/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4499 - accuracy: 0.8163 - val_loss: 0.4457 - val_accuracy: 0.8233
# Epoch 834/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4498 - accuracy: 0.8173 - val_loss: 0.4459 - val_accuracy: 0.8223
# Epoch 835/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4503 - accuracy: 0.8159 - val_loss: 0.4463 - val_accuracy: 0.8223
# Epoch 836/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4497 - accuracy: 0.8171 - val_loss: 0.4454 - val_accuracy: 0.8227
# Epoch 837/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4497 - accuracy: 0.8169 - val_loss: 0.4455 - val_accuracy: 0.8223
# Epoch 838/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4496 - accuracy: 0.8171 - val_loss: 0.4456 - val_accuracy: 0.8220
# Epoch 839/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4496 - accuracy: 0.8163 - val_loss: 0.4454 - val_accuracy: 0.8223
# Epoch 840/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4497 - accuracy: 0.8165 - val_loss: 0.4453 - val_accuracy: 0.8237
# Epoch 841/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4497 - accuracy: 0.8169 - val_loss: 0.4459 - val_accuracy: 0.8220
# Epoch 842/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4499 - accuracy: 0.8161 - val_loss: 0.4454 - val_accuracy: 0.8247
# Epoch 843/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4500 - accuracy: 0.8156 - val_loss: 0.4452 - val_accuracy: 0.8230
# Epoch 844/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4501 - accuracy: 0.8164 - val_loss: 0.4455 - val_accuracy: 0.8223
# Epoch 845/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4495 - accuracy: 0.8164 - val_loss: 0.4449 - val_accuracy: 0.8247
# Epoch 846/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4497 - accuracy: 0.8172 - val_loss: 0.4454 - val_accuracy: 0.8227
# Epoch 847/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4494 - accuracy: 0.8163 - val_loss: 0.4457 - val_accuracy: 0.8230
# Epoch 848/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4496 - accuracy: 0.8167 - val_loss: 0.4453 - val_accuracy: 0.8223
# Epoch 849/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4499 - accuracy: 0.8169 - val_loss: 0.4456 - val_accuracy: 0.8230
# Epoch 850/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4497 - accuracy: 0.8160 - val_loss: 0.4448 - val_accuracy: 0.8240
# Epoch 851/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4495 - accuracy: 0.8169 - val_loss: 0.4448 - val_accuracy: 0.8240
# Epoch 852/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4497 - accuracy: 0.8169 - val_loss: 0.4457 - val_accuracy: 0.8223
# Epoch 853/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4494 - accuracy: 0.8169 - val_loss: 0.4452 - val_accuracy: 0.8240
# Epoch 854/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4494 - accuracy: 0.8159 - val_loss: 0.4450 - val_accuracy: 0.8227
# Epoch 855/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4493 - accuracy: 0.8169 - val_loss: 0.4455 - val_accuracy: 0.8227
# Epoch 856/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4492 - accuracy: 0.8165 - val_loss: 0.4450 - val_accuracy: 0.8227
# Epoch 857/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4492 - accuracy: 0.8170 - val_loss: 0.4448 - val_accuracy: 0.8237
# Epoch 858/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4491 - accuracy: 0.8171 - val_loss: 0.4457 - val_accuracy: 0.8223
# Epoch 859/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4492 - accuracy: 0.8170 - val_loss: 0.4453 - val_accuracy: 0.8220
# Epoch 860/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4492 - accuracy: 0.8168 - val_loss: 0.4463 - val_accuracy: 0.8233
# Epoch 861/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4500 - accuracy: 0.8173 - val_loss: 0.4452 - val_accuracy: 0.8223
# Epoch 862/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4498 - accuracy: 0.8160 - val_loss: 0.4458 - val_accuracy: 0.8217
# Epoch 863/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4495 - accuracy: 0.8169 - val_loss: 0.4449 - val_accuracy: 0.8230
# Epoch 864/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4497 - accuracy: 0.8167 - val_loss: 0.4445 - val_accuracy: 0.8227
# Epoch 865/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4494 - accuracy: 0.8165 - val_loss: 0.4452 - val_accuracy: 0.8227
# Epoch 866/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4490 - accuracy: 0.8166 - val_loss: 0.4450 - val_accuracy: 0.8227
# Epoch 867/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4489 - accuracy: 0.8162 - val_loss: 0.4447 - val_accuracy: 0.8237
# Epoch 868/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4489 - accuracy: 0.8164 - val_loss: 0.4453 - val_accuracy: 0.8237
# Epoch 869/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4491 - accuracy: 0.8172 - val_loss: 0.4448 - val_accuracy: 0.8233
# Epoch 870/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4489 - accuracy: 0.8171 - val_loss: 0.4451 - val_accuracy: 0.8227
# Epoch 871/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4490 - accuracy: 0.8166 - val_loss: 0.4450 - val_accuracy: 0.8223
# Epoch 872/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4491 - accuracy: 0.8166 - val_loss: 0.4450 - val_accuracy: 0.8223
# Epoch 873/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4489 - accuracy: 0.8164 - val_loss: 0.4462 - val_accuracy: 0.8237
# Epoch 874/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4498 - accuracy: 0.8165 - val_loss: 0.4453 - val_accuracy: 0.8213
# Epoch 875/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4496 - accuracy: 0.8160 - val_loss: 0.4455 - val_accuracy: 0.8220
# Epoch 876/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4488 - accuracy: 0.8168 - val_loss: 0.4444 - val_accuracy: 0.8240
# Epoch 877/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4487 - accuracy: 0.8168 - val_loss: 0.4448 - val_accuracy: 0.8237
# Epoch 878/900
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4486 - accuracy: 0.8169 - val_loss: 0.4452 - val_accuracy: 0.8220
# Epoch 879/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4488 - accuracy: 0.8169 - val_loss: 0.4449 - val_accuracy: 0.8230
# Epoch 880/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4488 - accuracy: 0.8166 - val_loss: 0.4445 - val_accuracy: 0.8227
# Epoch 881/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4492 - accuracy: 0.8163 - val_loss: 0.4446 - val_accuracy: 0.8220
# Epoch 882/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4489 - accuracy: 0.8166 - val_loss: 0.4447 - val_accuracy: 0.8230
# Epoch 883/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4490 - accuracy: 0.8166 - val_loss: 0.4443 - val_accuracy: 0.8230
# Epoch 884/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4486 - accuracy: 0.8164 - val_loss: 0.4450 - val_accuracy: 0.8230
# Epoch 885/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4485 - accuracy: 0.8162 - val_loss: 0.4447 - val_accuracy: 0.8220
# Epoch 886/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4485 - accuracy: 0.8169 - val_loss: 0.4444 - val_accuracy: 0.8230
# Epoch 887/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4486 - accuracy: 0.8171 - val_loss: 0.4444 - val_accuracy: 0.8227
# Epoch 888/900
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4486 - accuracy: 0.8164 - val_loss: 0.4446 - val_accuracy: 0.8237
# Epoch 889/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4487 - accuracy: 0.8167 - val_loss: 0.4448 - val_accuracy: 0.8220
# Epoch 890/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4484 - accuracy: 0.8164 - val_loss: 0.4447 - val_accuracy: 0.8220
# Epoch 891/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4484 - accuracy: 0.8167 - val_loss: 0.4442 - val_accuracy: 0.8247
# Epoch 892/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4487 - accuracy: 0.8160 - val_loss: 0.4445 - val_accuracy: 0.8233
# Epoch 893/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4491 - accuracy: 0.8169 - val_loss: 0.4453 - val_accuracy: 0.8207
# Epoch 894/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4485 - accuracy: 0.8167 - val_loss: 0.4440 - val_accuracy: 0.8240
# Epoch 895/900
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4486 - accuracy: 0.8172 - val_loss: 0.4443 - val_accuracy: 0.8223
# Epoch 896/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4482 - accuracy: 0.8176 - val_loss: 0.4449 - val_accuracy: 0.8220
# Epoch 897/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4485 - accuracy: 0.8167 - val_loss: 0.4441 - val_accuracy: 0.8230
# Epoch 898/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4483 - accuracy: 0.8171 - val_loss: 0.4444 - val_accuracy: 0.8227
# Epoch 899/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4483 - accuracy: 0.8174 - val_loss: 0.4445 - val_accuracy: 0.8220
# Epoch 900/900
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4482 - accuracy: 0.8169 - val_loss: 0.4447 - val_accuracy: 0.8233
# Pipeline(steps=[('create_model',
#                  CreateModel(batch_size=900, epochs=2500, input_s=9))])

# %% [markdown]
# Agora que temos uma pipeline completa, com etapas de pré-processamento configuradas e também um modelo por árvore de decisão já treinado, podemos realizar a integração com o Watson Machine Learning!

# %% [markdown]
# ### Encapsulando uma Pipeline personalizada no Watson Machine Learning

# %% [markdown]
# #### Estabelecendo conexão entre o cliente Python do WML e a sua instância do serviço na nuvem

# %%
# Biblioteca Python com implementação de um cliente HTTP para a API do WML
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %% [markdown]
# As próximas células irão realizar o deploy da pipeline declarada neste notebook no WML. Só prossiga se você já está satisfeito com seu modelo e acha que já é a hora de fazer o deploy da sua solução.
#
# Cole as credenciais de sua instância do Watson Machine Learning na variável na célula abaixo.
#
# É importante que a variável que contém os valores tenha o nome de ``wml_credentials`` para que as próximas células deste notebook executem corretamente.

# %%
wml_credentials = {
  "apikey": "",
  "iam_apikey_description": "",
  "iam_apikey_name": "",
  "iam_role_crn": "",
  "iam_serviceid_crn": "",
  "instance_id": "",
  "url": ""
}

# %%
# Instanciando um objeto cliente do Watson Machine Learning a partir das credenciais fornecidas

clientWML = WatsonMachineLearningAPIClient(wml_credentials)

# %%
# Extraindo detalhes da sua instância do Watson Machine Learning

instance_details = clientWML.service_instance.get_details()
print(json.dumps(instance_details, indent=4))

# %% [markdown]
# **ATENÇÃO!!**
#
# Fique atento para os limites de consumo de sua instância do Watson Machine Learning!
#
# Caso você expire a camada grátis, não será possível avaliar seu modelo (pois é necessária a realização de algumas chamadas de API que consomem predições!)

# %% [markdown]
# #### Listando todos os artefatos armazenados no seu WML

# %% [markdown]
# Para listar todos os artefatos armazenados em seu Watson Machine Learning, você pode usar a seguinte função:
#
#     clientWML.repository.list()

# %%
# Listando todos os artefatos atualmente armazenados na sua instância do WML

clientWML.repository.list()

# %% [markdown]
# No plano LITE do Watson Machine Learning só é permitido o deploy de um único modelo por vez. Se for o caso de você já possuir um modelo online na sua instância, você pode apagá-lo utilizando o método clientWML.repository.delete():
#
#     artifact_guid = "359c8951-d2fe-4063-8706-cc06b32d5e0d"
#     clientWML.repository.delete(artifact_guid)

# %% [markdown]
# #### Criando uma nova definição de pacote Python personalizado no WML

# %% [markdown]
# O primeiro passo para realizar seu deploy é armazenar o código das transformações personalizadas criadas por você.
#
# Para essa etapa precisamos apenas do arquivo .zip do pacote criado (que já possuimos carregado no Kernel!)

# %%
# Definição de metadados do nosso pacote com as Transforms personalizadas
pkg_meta = {
    clientWML.runtimes.LibraryMetaNames.NAME: "my_custom_sklearn_transform_1",
    clientWML.runtimes.LibraryMetaNames.DESCRIPTION: "A custom sklearn transform",
    clientWML.runtimes.LibraryMetaNames.FILEPATH: "sklearn_transforms.zip",  # Note que estamos utilizando o .zip criado anteriormente!
    clientWML.runtimes.LibraryMetaNames.VERSION: "1.0",
    clientWML.runtimes.LibraryMetaNames.PLATFORM: { "name": "python", "versions": ["3.6"] }
}
custom_package_details = clientWML.runtimes.store_library( pkg_meta )
custom_package_uid = clientWML.runtimes.get_library_uid( custom_package_details )

print("\n Lista de artefatos de runtime armazenados no WML:")
clientWML.repository.list()

# %% [markdown]
# #### Criando uma nova definição de runtime Python personalizado no WML
#
# O segundo passo é armazenar uma definição de runtime Python para utilizar a nossa biblioteca personalizada.
#
# Isso pode ser feito da seguinte forma:

# %%
runtime_meta = {
    clientWML.runtimes.ConfigurationMetaNames.NAME: "my_custom_wml_runtime_1",
    clientWML.runtimes.ConfigurationMetaNames.DESCRIPTION: "A Python runtime with custom sklearn Transforms",
    clientWML.runtimes.ConfigurationMetaNames.PLATFORM: {
        "name": "python",
        "version": "3.6"
    },
    clientWML.runtimes.ConfigurationMetaNames.LIBRARIES_UIDS: [ custom_package_uid ]
}
runtime_details = clientWML.runtimes.store( runtime_meta )
custom_runtime_uid = clientWML.runtimes.get_uid( runtime_details )

print("\n Detalhes do runtime armazenado:")
print(json.dumps(runtime_details, indent=4))

# %%
# Listando todos runtimes armazenados no seu WML:
clientWML.runtimes.list()

# %% [markdown]
# #### Criando uma nova definição de Pipeline personalizada no WML
#
# Finalmente iremos criar uma definição (metadados) para a nossa Pipeline ser hospedada no WML.
#
# Definimos como parâmetros um nome para o artefato e o ID do runtime criado anteriormente.

# %%
model_meta = {
    clientWML.repository.ModelMetaNames.NAME: 'desafio-2-mbtc2020-pipeline-1',
    clientWML.repository.ModelMetaNames.DESCRIPTION: "my pipeline for submission",
    clientWML.repository.ModelMetaNames.RUNTIME_UID: custom_runtime_uid
}

# %% [markdown]
# Em seguida chamamos o método para armazenar a nova definição:

# %%
# Função para armazenar uma definição de Pipeline no WML
stored_model_details = clientWML.repository.store_model(
    model=my_pipeline,  # `my_pipeline` é a variável criada anteriormente e contém nossa Pipeline já treinada :)
    meta_props=model_meta,  # Metadados definidos na célula anterior
    training_data=None  # Não altere esse parâmetro
)

print("\n Lista de artefatos armazenados no WML:")
clientWML.repository.list()

# Detalhes do modelo hospedado no Watson Machine Learning
print("\n Metadados do modelo armazenado:")
print(json.dumps(stored_model_details, indent=4))

# %% [markdown]
# #### Realizando o deployment do seu modelo para consumo imediato por outras aplicações

# %%
# O deployment do modelo é finalmente realizado por meio do método ``deployments.create()``

model_deployment_details = clientWML.deployments.create(
    artifact_uid=stored_model_details["metadata"]["guid"],  # Não altere esse parâmetro
    name="desafio-2-mbtc2020-deployment-1",
    description="Solução do desafio 2 - MBTC",
    asynchronous=False,  # Não altere esse parâmetro
    deployment_type='online',  # Não altere esse parâmetro
    deployment_format='Core ML',  # Não altere esse parâmetro
    meta_props=model_meta  # Não altere esse parâmetro
)

# %% [markdown]
# #### Testando um modelo hospedado no Watson Machine Learning

# %%
# Recuperando a URL endpoint do modelo hospedado na célula anterior

model_endpoint_url = clientWML.deployments.get_scoring_url(model_deployment_details)
print("A URL de chamada da sua API é: {}".format(model_endpoint_url))

# %%
# Detalhes do deployment realizado

deployment_details = clientWML.deployments.get_details(
    deployment_uid=model_deployment_details["metadata"]["guid"]  # esse é o ID do seu deployment!
)

print("Metadados do deployment realizado: \n")
print(json.dumps(deployment_details, indent=4))

# %%
scoring_payload = {
    'fields': [
        "MATRICULA", "NOME", 'REPROVACOES_DE', 'REPROVACOES_EM', "REPROVACOES_MF", "REPROVACOES_GO",
        "NOTA_DE", "NOTA_EM", "NOTA_MF", "NOTA_GO",
        "INGLES", "H_AULA_PRES", "TAREFAS_ONLINE", "FALTAS", 
    ],
    'values': [
        [
            513949,"Marli Quésia de Oliveira",1,1,1,1,4.3,4.0,3.1,4.9,0,3,4,3,
        ]
    ]
}

print("\n Payload de dados a ser classificada:")
print(json.dumps(scoring_payload, indent=4))

# %%
result = clientWML.deployments.score(
    model_endpoint_url,
    scoring_payload
)

print("\n Resultados:")
print(json.dumps(result, indent=4))

# %% [markdown]
# <hr>
#
# ## Parabéns!
#
# Se tudo foi executado sem erros, você já tem um classificador baseado em machine learning encapsulado como uma API REST!
#
# Para testar a sua solução integrada com um assistente virtual e realizar a submissão, acesse a página:
#
# https://uninassau.maratona.dev
#
# Você irá precisar da endpoint url do seu modelo e das credenciais do WML :)
